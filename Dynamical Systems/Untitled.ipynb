# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
weights = np.array([[1,2],[3,4]])
var = np.array([3,2]).reshape(-1,1)

# %%
np.power(-2,1/3)
# Out:
# /home/ali/anaconda3/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in power
#   """Entry point for launching an IPython kernel.
# nan

# %%
weights@var
# Out:
# array([[ 7],
#        [17]])

# %%
r = np.linspace(0,10,100)
th = np.linspace(0,0.3*np.pi,100)

# %%
plt.polar(th, (1+np.tan(th))**0.5)

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
x = np.outer(np.linspace(-2, 2, 30), 1*np.ones(30))
y = x.copy().T # transpose
z = np.cos(x ** 2 + y ** 2)

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()

# %%
x.shape
# Out:
# (30, 30)

# %%
plt.imshow(z)

# %%
x[-1]
# Out:
# array([4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.])

# %%
def update_var_dot(var_x, var_y):
    var_dot_x = var_x - var_x**2 - var_x*var_y
    var_dot_y = 3*var_y - var_x*var_y - 2*var_y**2

    return var_dot_x, var_dot_y

# %%
var_x = np.outer(np.linspace(-2, 2, 3), 1*np.ones(3))
var_y = var_x.copy().T

# %%
var_dot_x, var_dot_y = update_var_dot(var_x, var_y)

# %%
1/var_x
# Out:
# /home/ali/anaconda3/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[-0.5, -0.5, -0.5],
#        [ inf,  inf,  inf],
#        [ 0.5,  0.5,  0.5]])

# %%
for i, x_ in enumerate(var_x[:,0]):
    for j, y_ in enumerate(var_y[0,:]):
        plt.arrow(x_,y_,var_dot_x[i,j], var_dot_y[i,j])

# %%
a = [1,2,3,4,5,6]

# %%
a[1:-1]
# Out:
# [2, 3, 4, 5]
